# %% [markdown]
# # INTRODUCCIÓN A TENSORFLOW 2.X - KERAS

# %% [markdown]
# ## 1. Tensorflow y Keras
#
# **Tensorflow** es una potente librería de código abierto desarrollada por Google (febrero 2017, v1.0) para la creación de redes neuronales profundas de manera completa. Existen otros paquetes de software libre como *Pytorch* o *MxNet*. que son también utilizados en Deep Learning; si bien, su popularidad entre la comunidad de científicos de datos es, a día de hoy, inferior a Tensorflow.
#
# Entre las principales ventajas de utilizar Tensorflow se encuentran:
# - Trabaja con lenguajes como Python, R, Java, C++ y Go
# - Keras viene integrado en Tensorflow 2.0
# - Permite la realización de cálculos en paralelo lo que reduce el tiempo de ejecución
# - Permite el desarrollo de modelos y su puesta en producción de forma ágil
# - Actualmente dispone de una comunidad de soporte mucho más avanzada que el resto de frameworks
#
# La llamada al módulo de Keras en la versión 2.0 (o superior) de Tensorflow tiene lugar mediante *tf.keras*; si bien, destacar que existen ligeras diferencias entre el módulo soportado y la propia librería. Por todo ello, siempre que se trabaje con Tensorflow se recomienda emplear el módulo *tf.keras* pues que permite una total integración.
#
# Con *tf.keras* se pueden modelos mediante diferentes métodos:
# - **Secuencial:** adecuado para una pila simple de capas (cada una de ellas tiene exactamente un tensor de entrada y otro de salida). Es el método más sencillo
# - **Funcional:** permite crear modelos de forma más dinámica que mediante el método *Sequential*. De gran utilidad para desarrollar modelos con capas compartidas, multiples entradas-salidas o de topología no lineal. Es el más utilizado en la industria pues, prácticamente, todos los proyectos de Deep Learning pueden definirse siguiendo este método
# - **Modular:** permite la generación de modelos de redes neuonales profundas muy específicos. Suele ser utilizado en entornos de investigación académica

# %%
import tensorflow as tf
print('Version:', tf.__version__)
# Out:
# Version: 2.12.0

# %% [markdown]
# ## 1. Primera Red Neuronal en tf 2.x
#
# ### 1.1 Entrenamiento de una red neuronal Simple
#
# Para la creación de nuestra primera red neuronal se va a emplear la base de datos MNIST. Esta base de datos, de las más importantes a nivel aprendizaje supervisado, es un conjunto de 70.000 imágenes en escala de grises de digitos escritos a mano.
#
# Destacar que, por sencillez, se va a diseñar una arquitectura de Deep Learning compuesta por redes densamente conectadas. Por su parte, para ilustrar los dos primeros métodos de *tf.keras*, la arquitectura de la red será creada siguiendo tanto el método secuencial como el funcional.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import mnist 


(X_train, Y_train), (X_test, Y_test) = mnist.load_data() # carga de datos (train y test)

# %% [markdown]
# Como puede verse, se tiene como tensor de entrada el número de imágenes y la dimensión (alto-ancho)

# %%
print('X - train:', X_train.shape)
print('X - test:', X_test.shape)
# Out:
# X - train: (60000, 28, 28)
# X - test: (10000, 28, 28)

# %% [markdown]
# Sin embargo, cuando se trabaja con redes densamente conectadas, es necesario redefinir el tamaño de la entrada a una matriz de *nxm* (donde n es el número de muestras y m es el número de píxeles de la imagen).

# %%
remodelado = X_train.shape[1]*X_train.shape[2] # 784 neuronas de entrada -> 28*28

# redifinición de los datos de entrada a la red (train y test)
X_train = X_train.reshape(X_train.shape[0], remodelado)
X_test = X_test.reshape(X_test.shape[0], remodelado)

# %% [markdown]
# Se observa que el tamaño ha variado pero el número de muestras se mantiene.

# %%
print('X - train:', X_train.shape)
print('X - test:', X_test.shape)
# Out:
# X - train: (60000, 784)
# X - test: (10000, 784)

# %% [markdown]
# Adicionalmente, para mejorar el aprendizaje de la red, los valores asociados con cada pixel son normalizados en función de la intensidad (normalización entre 0 y 1). Para ello, se dividen los datos de entrada entre 255 (color blanco en la escala RGB).

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# Como todo aprendizaje supervisado, el target es un vector de etiquetas. En este caso, se tiene un problema de clasificación multinivel (10 clases, cada una un dígito). Por tanto, se convierte a variable dummy las etiquetas.

# %%
num_clase = 10

Y_train = tf.keras.utils.to_categorical(Y_train,num_clase)
Y_test = tf.keras.utils.to_categorical(Y_test,num_clase)

print('Y - train:', Y_train.shape)
print('Y - test:', Y_test.shape)
# Out:
# Y - train: (60000, 10)
# Y - test: (10000, 10)

# %% [markdown]
# Una vez realizado el procesado de los datos de entrada se procede con la definición de la arquitectura de la red. Para ello, hay que tener en cuenta, al menos, las siguientes consideraciones:
# - Datos de entrada: 784 neuronas en la capa de entrada a la red
# - Datos de salida: 10 neuronas salida de la red (activación softmax para tener una probabilidad entre 0 y 1 para cada categoría)
# - Capas intermedias: número de capas y neuronas que consideremos apropiado según el proyecto (incluyendo la elección de la función de activación)
#
# En este caso, se diseña una red neuronal con una única capa intermedia con 16 neuronas y función de activación lineal.
#
# #### 1.1.1 Arquitectura de la red
#
# Como se ha comentado inicialmente, se crea la red siguiendo los métodos *Sequential* y *Funcional* de *tf.keras*:

# %% [markdown]
# **Sequential**

# %%
# definición del modelo secuencial
model_sequential = tf.keras.models.Sequential()
# capa de entrada e intermedia
model_sequential.add(tf.keras.layers.Dense(units=16, activation='linear', input_shape=(remodelado,)))
# capa de salida: no se necesita definir su capa de entrada al ser un modelo secuencial
model_sequential.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# En la siguiente tabla se presenta un resumen de las capas y parámetros de la red.

# %%
model_sequential.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                12560
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se observa que que la red tiene 3 capas (entrada, oculta y salida) y un total de 12.730 parámetros (los cuales son todos entrenables). Asimismo, los parámetros por capa son:
# - Oculta: entrada_nnet * neuronas_hidden + bias_hidden = 784 * 16 + 16
# - Salida: entrada_hidden * neuronas_out + bias_out = 16 * 10 + 10

# %% [markdown]
# **Funcional**

# %%
# capa de entrada
inputs = tf.keras.Input(shape=(remodelado,))
# capa oculta (a la que se le indica cuál es la capa anterior)
hidden = tf.keras.layers.Dense(units=16, activation='linear')(inputs)
# capa de salida (a la que se le indica cuál es la capa anterior)
out = tf.keras.layers.Dense(units=num_clase, activation='softmax')(hidden)
# definición del modelo funcional
model_funcional = tf.keras.Model(inputs=inputs, outputs=out)

# %%
model_funcional.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense_2 (Dense)             (None, 16)                12560
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Como puede verse, mediante el método funcional se dispone del mismo número de parámetros (y capas) que a partir del secuencial. Notar aquí la diferente forma de codificar el mismo diseño de red neuronal, esto es, mientras que en el método *Sequential* la capa de entrada se define en la capa intermedia, el método *Funcional* requiere de su definición como input.
#
# #### 1.1.2 Proceso de entranamiento
#
# Una vez diseñada la arquitectura de nuestra primera red neuronal profunda, es momento de la compilación y el entrenamiento de la misma. El proceso de entrenamiento de una red neuronal es un proceso iterativo que consiste en minimizar el valor de una **función objetivo** a partir de un algoritmo de optimización, típicamente el **Gradiente Descendiente** (o modificaciones de éste). Así, durante las diferentes etapas del entrenamiento, los valores de los pesos de la red neuronal se van actualizando. Por último, se disponde de una métrica para evaluar la bondad de ajuste del modelo.
#
# - **Función objetivo:** también conocida como *función de pérdida*, es una función que debe ser continua y derivable y es específica proyecto en cuestión. En este caso, al ser un problema de clasificación multiclase, se emplea *categorical_crossentropy*
# - **Optimizador:** existen diferentes algoritmos para minimizar el error de la *función de pérdida*. El más conocido es el *Gradiente Descendente Estocástico*; si bien, más adelante veremos otros que suelen mejorar las estimaciones de la red
# - **Métrica:** cualquier métrica que permite evaluar el error del modelo (accuracy, error cuadrático medio, área bajo la curva roc, etc.)
#
# Adicionalmente, destacar que **Tensorflow** permite definir tanto métricas como funciones objetivo propias del usuario; si bien, ese tipo de casuísticas solo se suele darse en proyectos de investigación.
#
# Así, se procede a compilar la red definida con el método funcional:

# %%
model_funcional.compile(optimizer='SGD', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

# %% [markdown]
# Por último, se lleva a cabo el entrenamiento de la red. Para ello, al ser un proceso iterativo se debe tener en cuenta los siguientes conceptos:
# - Épocas: número de veces que el modelo es expuesto al entrenamiento. En cada iteración, se trata de minimizar la función de pérdida, siendo actualizados los pesos de la red por el optimizador.
# - Lote: número de instancias utilizadas en el entrenamiento antes de que el optimizador actualize los pesos de la red
#
# A la hora de realizar el entrenamiento, es importante reservar una muestra de los datos de entrenamiento para su validación

# %%
tf.random.set_seed(123)

epoca = 50
lote = 128
validacion = 0.2 

history = model_funcional.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 4ms/step - loss: 1.3144 - accuracy: 0.6520 - val_loss: 0.7796 - val_accuracy: 0.8214
# Epoch 2/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.6758 - accuracy: 0.8334 - val_loss: 0.5367 - val_accuracy: 0.8646
# Epoch 3/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5281 - accuracy: 0.8595 - val_loss: 0.4524 - val_accuracy: 0.8802
# Epoch 4/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4636 - accuracy: 0.8721 - val_loss: 0.4091 - val_accuracy: 0.8884
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4267 - accuracy: 0.8804 - val_loss: 0.3838 - val_accuracy: 0.8939
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4027 - accuracy: 0.8859 - val_loss: 0.3655 - val_accuracy: 0.8992
# Epoch 7/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3855 - accuracy: 0.8900 - val_loss: 0.3532 - val_accuracy: 0.9010
# Epoch 8/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3724 - accuracy: 0.8937 - val_loss: 0.3433 - val_accuracy: 0.9025
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3622 - accuracy: 0.8964 - val_loss: 0.3355 - val_accuracy: 0.9062
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3537 - accuracy: 0.8986 - val_loss: 0.3290 - val_accuracy: 0.9074
# Epoch 11/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3465 - accuracy: 0.9007 - val_loss: 0.3239 - val_accuracy: 0.9086
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3405 - accuracy: 0.9020 - val_loss: 0.3199 - val_accuracy: 0.9092
# Epoch 13/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3354 - accuracy: 0.9038 - val_loss: 0.3157 - val_accuracy: 0.9104
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3308 - accuracy: 0.9053 - val_loss: 0.3118 - val_accuracy: 0.9112
# Epoch 15/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3267 - accuracy: 0.9062 - val_loss: 0.3091 - val_accuracy: 0.9123
# Epoch 16/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3232 - accuracy: 0.9075 - val_loss: 0.3059 - val_accuracy: 0.9136
# Epoch 17/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3199 - accuracy: 0.9085 - val_loss: 0.3038 - val_accuracy: 0.9147
# Epoch 18/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3169 - accuracy: 0.9094 - val_loss: 0.3014 - val_accuracy: 0.9150
# Epoch 19/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3141 - accuracy: 0.9101 - val_loss: 0.2997 - val_accuracy: 0.9156
# Epoch 20/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3117 - accuracy: 0.9113 - val_loss: 0.2977 - val_accuracy: 0.9164
# Epoch 21/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3094 - accuracy: 0.9117 - val_loss: 0.2960 - val_accuracy: 0.9166
# Epoch 22/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3072 - accuracy: 0.9125 - val_loss: 0.2942 - val_accuracy: 0.9171
# Epoch 23/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3052 - accuracy: 0.9133 - val_loss: 0.2929 - val_accuracy: 0.9169
# Epoch 24/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3034 - accuracy: 0.9138 - val_loss: 0.2917 - val_accuracy: 0.9171
# Epoch 25/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3017 - accuracy: 0.9143 - val_loss: 0.2910 - val_accuracy: 0.9183
# Epoch 26/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3001 - accuracy: 0.9148 - val_loss: 0.2892 - val_accuracy: 0.9178
# Epoch 27/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2986 - accuracy: 0.9151 - val_loss: 0.2881 - val_accuracy: 0.9185
# Epoch 28/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2970 - accuracy: 0.9158 - val_loss: 0.2873 - val_accuracy: 0.9189
# Epoch 29/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2958 - accuracy: 0.9159 - val_loss: 0.2867 - val_accuracy: 0.9193
# Epoch 30/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2946 - accuracy: 0.9166 - val_loss: 0.2854 - val_accuracy: 0.9197
# Epoch 31/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2933 - accuracy: 0.9174 - val_loss: 0.2844 - val_accuracy: 0.9197
# Epoch 32/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2921 - accuracy: 0.9173 - val_loss: 0.2839 - val_accuracy: 0.9206
# Epoch 33/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2910 - accuracy: 0.9175 - val_loss: 0.2832 - val_accuracy: 0.9211
# Epoch 34/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2898 - accuracy: 0.9181 - val_loss: 0.2828 - val_accuracy: 0.9202
# Epoch 35/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2889 - accuracy: 0.9180 - val_loss: 0.2821 - val_accuracy: 0.9216
# Epoch 36/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2879 - accuracy: 0.9181 - val_loss: 0.2814 - val_accuracy: 0.9219
# Epoch 37/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2870 - accuracy: 0.9189 - val_loss: 0.2806 - val_accuracy: 0.9214
# Epoch 38/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2861 - accuracy: 0.9191 - val_loss: 0.2800 - val_accuracy: 0.9217
# Epoch 39/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2852 - accuracy: 0.9193 - val_loss: 0.2797 - val_accuracy: 0.9219
# Epoch 40/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2844 - accuracy: 0.9199 - val_loss: 0.2794 - val_accuracy: 0.9217
# Epoch 41/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2837 - accuracy: 0.9197 - val_loss: 0.2786 - val_accuracy: 0.9213
# Epoch 42/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2827 - accuracy: 0.9201 - val_loss: 0.2780 - val_accuracy: 0.9213
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2821 - accuracy: 0.9201 - val_loss: 0.2785 - val_accuracy: 0.9214
# Epoch 44/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2814 - accuracy: 0.9196 - val_loss: 0.2775 - val_accuracy: 0.9228
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2805 - accuracy: 0.9202 - val_loss: 0.2770 - val_accuracy: 0.9234
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2800 - accuracy: 0.9209 - val_loss: 0.2766 - val_accuracy: 0.9230
# Epoch 47/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2793 - accuracy: 0.9208 - val_loss: 0.2761 - val_accuracy: 0.9231
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2787 - accuracy: 0.9211 - val_loss: 0.2760 - val_accuracy: 0.9227
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2781 - accuracy: 0.9214 - val_loss: 0.2754 - val_accuracy: 0.9237
# Epoch 50/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2775 - accuracy: 0.9215 - val_loss: 0.2753 - val_accuracy: 0.9231

# %% [markdown]
# #### 1.1.3 Análisis de resultados
# Como puede verse, se tiene un ajuste superior al 90% en entrenamiento y validación. Veamos gráficamente el proceso de entrenamiento (loss y accuracy):

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# Si nos fijamos en la curvas de pérdida, la de entrenamiento está por encima de la de validación. Esto hecho, aunque posible, pero no suele ser usual ya que, generalmente, la red se ajusta mejor a los datos de entrenamiento.
# Adicionalmente, es importante destacar que, tras 50 épocas el proceso de convergencia de la red no ha llegado a su fin (curvas de loss y accuracy no son completamente planas).
#
# Por último, se evalua el desempeño del modelo en la muestra de test.

# %%
loss_test, acc_test = model_funcional.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.9205

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

Y_test_pred = np.argmax(model_funcional.predict(X_test), axis=1) # predicción de la muestra test - en formato etiqueta
Y_test_label = np.argmax(Y_test, axis=1) # muestra test en formato etiqueta
sns.heatmap(confusion_matrix(Y_test_pred, Y_test_label), annot = True, fmt='.0f') # matriz de confusión
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Como puede verse, el accuracy en la muestra de test es similar al obtenido en la muestra de entrenamiento y validación. Asimismo, se observa en matriz de confusión como la clasificación de los diez dígitos tiene un elevado grado de acierto.

# %% [markdown]
# ## 2. Mejorando la red neuronal
#
# Se ha visto que la red neuronal anterior tiene una buena bondad de ajuste (por encima del 90%) y un número de parámetros un 20% inferior a los datos de partida. A pesar de que podríamos decir que es un muy buen modelo, es posible mejorar el modelo empleando:
# - Más capas ocultas: manteniendo siempre una proporcionalidad entre parámetros/datos y evitando el sobreentrenamiento
# - Funciones de activación: probaremos la función *ReLu* (la más apropiada para modelos con múltiples capas ocultas)
# - Inicialización de los pesos: suele emplearse la inialización de Xavier/Glorot (por defecto en *tf.keras*) pero hay otras como inicialización aleatoria, normalizada, Lecun, etc.
# - Optimizadores: Adam (utilizado en la mayor parte de los problemas de deep learning), AdaGrad, RMSProp, etc.
#
# Por contra, muchas veces al entrenar el modelo se cae en el sobreajuste de los datos. Para evitarlo, se emplean técnicas de parada temprana o de regularización. Las técnicas de regularización más comunes son:
# - Dropout: eliminación al azar de algunas de las neuronas de la red en el entrenamiento por lotes (para la predicción se usan todas las neuronas)
# - L1, L2, Elastic Net: modificación de la función de pérdida en función de un factor dependiendo de los pesos de la red (norma, cuadrado o combianción de las dos, respectivamente)
#
# Finalmente, la búsqueda de los parámetros más adecuados para el problema es un hecho diferenciador a la hora de encontrar la máxima bondad de ajuste. Si se tiene cierto conocimiento sobre el ámbito del proyecto puede ser de gran utilidad una búsqueda "fina" de forma aleatoria, pero se recomienda que el usuario monitoriza la modificación de los parámetros:
# - Arquitectura de la red (número de capas, neuronas o función de activación)
# - Número de épocas o tamaño del batch
# - Diferentes técnicas de regularización
#
# Una vez comentados los aspectos teóricos, se procede a realizar diferentes propuestas para mejorar el modelo anterior que lo utilizaremos como base; es decir, si no se mejora la bondad de ajuste serán rechazadas las diferentes propuestas.
#
# ### 2.1 Propuestas de mejora

# %% [markdown]
# #### 2.1.1. Aumento de capas ocultas y optimizador de Adam
#
# Se incorporan dos capas ocultas de 8 neuronas y función de activación *ReLu* (salvo en la capa de salida). Asimismo, se empleará *Adam* como optimizador.

# %%
# dropout=0.2

model_1 = tf.keras.models.Sequential()
model_1.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
# model_1.add(tf.keras.layers.Dropout(dropout))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# Como puede verse en la tabla resumen, el número de parámetros ha aumentado ligeramente al incluir dos capas intermedias más.

# %%
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16)                12560
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 10)                90
#
# =================================================================
# Total params: 12,858
# Trainable params: 12,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se compila y se hace el entrenamiento de este nuevo modelo.

# %%
model_1.compile(optimizer='adam', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_1.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 5ms/step - loss: 1.0203 - accuracy: 0.6797 - val_loss: 0.4354 - val_accuracy: 0.8812
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4055 - accuracy: 0.8856 - val_loss: 0.3591 - val_accuracy: 0.9004
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3448 - accuracy: 0.9033 - val_loss: 0.3215 - val_accuracy: 0.9100
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3084 - accuracy: 0.9124 - val_loss: 0.2938 - val_accuracy: 0.9184
# Epoch 5/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2837 - accuracy: 0.9193 - val_loss: 0.2742 - val_accuracy: 0.9237
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2618 - accuracy: 0.9260 - val_loss: 0.2707 - val_accuracy: 0.9253
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2450 - accuracy: 0.9308 - val_loss: 0.2546 - val_accuracy: 0.9277
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2345 - accuracy: 0.9332 - val_loss: 0.2542 - val_accuracy: 0.9293
# Epoch 9/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2234 - accuracy: 0.9363 - val_loss: 0.2369 - val_accuracy: 0.9333
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2146 - accuracy: 0.9378 - val_loss: 0.2344 - val_accuracy: 0.9368
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2066 - accuracy: 0.9406 - val_loss: 0.2343 - val_accuracy: 0.9349
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2008 - accuracy: 0.9421 - val_loss: 0.2275 - val_accuracy: 0.9374
# Epoch 13/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1943 - accuracy: 0.9434 - val_loss: 0.2266 - val_accuracy: 0.9365
# Epoch 14/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1894 - accuracy: 0.9456 - val_loss: 0.2215 - val_accuracy: 0.9372
# Epoch 15/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1842 - accuracy: 0.9461 - val_loss: 0.2180 - val_accuracy: 0.9363
# Epoch 16/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1809 - accuracy: 0.9471 - val_loss: 0.2152 - val_accuracy: 0.9395
# Epoch 17/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1754 - accuracy: 0.9493 - val_loss: 0.2146 - val_accuracy: 0.9387
# Epoch 18/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1722 - accuracy: 0.9503 - val_loss: 0.2112 - val_accuracy: 0.9412
# Epoch 19/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1677 - accuracy: 0.9508 - val_loss: 0.2125 - val_accuracy: 0.9392
# Epoch 20/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1642 - accuracy: 0.9508 - val_loss: 0.2042 - val_accuracy: 0.9442
# Epoch 21/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1619 - accuracy: 0.9526 - val_loss: 0.2115 - val_accuracy: 0.9417
# Epoch 22/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1593 - accuracy: 0.9534 - val_loss: 0.2096 - val_accuracy: 0.9421
# Epoch 23/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1551 - accuracy: 0.9543 - val_loss: 0.2055 - val_accuracy: 0.9435
# Epoch 24/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1526 - accuracy: 0.9552 - val_loss: 0.2068 - val_accuracy: 0.9435
# Epoch 25/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1505 - accuracy: 0.9557 - val_loss: 0.2072 - val_accuracy: 0.9419
# Epoch 26/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1488 - accuracy: 0.9561 - val_loss: 0.2068 - val_accuracy: 0.9409
# Epoch 27/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1459 - accuracy: 0.9569 - val_loss: 0.2060 - val_accuracy: 0.9452
# Epoch 28/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1430 - accuracy: 0.9585 - val_loss: 0.2032 - val_accuracy: 0.9456
# Epoch 29/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1407 - accuracy: 0.9587 - val_loss: 0.2076 - val_accuracy: 0.9423
# Epoch 30/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1383 - accuracy: 0.9590 - val_loss: 0.2079 - val_accuracy: 0.9420
# Epoch 31/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1382 - accuracy: 0.9595 - val_loss: 0.2042 - val_accuracy: 0.9440
# Epoch 32/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1348 - accuracy: 0.9606 - val_loss: 0.2050 - val_accuracy: 0.9433
# Epoch 33/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1323 - accuracy: 0.9615 - val_loss: 0.2091 - val_accuracy: 0.9442
# Epoch 34/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1316 - accuracy: 0.9614 - val_loss: 0.2058 - val_accuracy: 0.9444
# Epoch 35/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1295 - accuracy: 0.9625 - val_loss: 0.2091 - val_accuracy: 0.9427
# Epoch 36/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1289 - accuracy: 0.9620 - val_loss: 0.2209 - val_accuracy: 0.9428
# Epoch 37/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1267 - accuracy: 0.9628 - val_loss: 0.2189 - val_accuracy: 0.9386
# Epoch 38/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1251 - accuracy: 0.9630 - val_loss: 0.2153 - val_accuracy: 0.9433
# Epoch 39/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1222 - accuracy: 0.9648 - val_loss: 0.2132 - val_accuracy: 0.9423
# Epoch 40/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1219 - accuracy: 0.9646 - val_loss: 0.2198 - val_accuracy: 0.9417
# Epoch 41/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1204 - accuracy: 0.9652 - val_loss: 0.2129 - val_accuracy: 0.9428
# Epoch 42/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1192 - accuracy: 0.9650 - val_loss: 0.2153 - val_accuracy: 0.9433
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1200 - accuracy: 0.9646 - val_loss: 0.2094 - val_accuracy: 0.9445
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1168 - accuracy: 0.9655 - val_loss: 0.2125 - val_accuracy: 0.9431
# Epoch 45/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1159 - accuracy: 0.9667 - val_loss: 0.2349 - val_accuracy: 0.9387
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1155 - accuracy: 0.9658 - val_loss: 0.2158 - val_accuracy: 0.9436
# Epoch 47/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1142 - accuracy: 0.9667 - val_loss: 0.2181 - val_accuracy: 0.9448
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1118 - accuracy: 0.9666 - val_loss: 0.2166 - val_accuracy: 0.9438
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1111 - accuracy: 0.9675 - val_loss: 0.2207 - val_accuracy: 0.9438
# Epoch 50/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1103 - accuracy: 0.9671 - val_loss: 0.2236 - val_accuracy: 0.9421

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# Como puede verse, la red empieza a sobreajustar desde las primeras épocas pero, a la vista del resultado en la muestra de test, el modelo tiene una alta capacidad predictiva.

# %%
loss_test, acc_test = model_1.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.2339 - accuracy: 0.9426

# %% [markdown]
# Se deja al alumno la creación de un modelo con una capa de dropout (descomentar las líneas de código de la arquitectura).

# %% [markdown]
# #### 2.1.2 Regularización de los pesos de la red
#
# Se incorpora la regularización L2 a las capas de 8 neuronas. El valor de la regularización será de 0.01.

# %%
l2_value=0.01

model_2 = tf.keras.models.Sequential()
model_2.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_2.add(tf.keras.layers.Dense(units=8, 
                                 activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(l2_value)))
model_2.add(tf.keras.layers.Dense(units=8, 
                                 activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(l2_value)))
model_2.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# Puede verse que el número de capas y los parámetros del modelo son los mismos que en la primera propuesta.

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 16)                12560
#
#  dense_9 (Dense)             (None, 8)                 136
#
#  dense_10 (Dense)            (None, 8)                 72
#
#  dense_11 (Dense)            (None, 10)                90
#
# =================================================================
# Total params: 12,858
# Trainable params: 12,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se compila y se hace el entrenamiento de esta nueva propuesta. En este caso, también se emplea *Adam* como optimizador.

# %%
model_2.compile(optimizer='adam', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_2.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 3ms/step - loss: 1.2585 - accuracy: 0.6594 - val_loss: 0.7341 - val_accuracy: 0.8501
# Epoch 2/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.6837 - accuracy: 0.8622 - val_loss: 0.5959 - val_accuracy: 0.8847
# Epoch 3/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5854 - accuracy: 0.8869 - val_loss: 0.5375 - val_accuracy: 0.8987
# Epoch 4/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.5273 - accuracy: 0.9005 - val_loss: 0.4869 - val_accuracy: 0.9089
# Epoch 5/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4851 - accuracy: 0.9087 - val_loss: 0.4569 - val_accuracy: 0.9153
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4537 - accuracy: 0.9155 - val_loss: 0.4302 - val_accuracy: 0.9215
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4257 - accuracy: 0.9208 - val_loss: 0.4094 - val_accuracy: 0.9270
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.4027 - accuracy: 0.9253 - val_loss: 0.3892 - val_accuracy: 0.9298
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3836 - accuracy: 0.9286 - val_loss: 0.3717 - val_accuracy: 0.9337
# Epoch 10/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3667 - accuracy: 0.9312 - val_loss: 0.3584 - val_accuracy: 0.9360
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3523 - accuracy: 0.9340 - val_loss: 0.3484 - val_accuracy: 0.9362
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3397 - accuracy: 0.9358 - val_loss: 0.3375 - val_accuracy: 0.9359
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3275 - accuracy: 0.9381 - val_loss: 0.3262 - val_accuracy: 0.9379
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3172 - accuracy: 0.9392 - val_loss: 0.3172 - val_accuracy: 0.9389
# Epoch 15/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3072 - accuracy: 0.9405 - val_loss: 0.3142 - val_accuracy: 0.9383
# Epoch 16/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2982 - accuracy: 0.9419 - val_loss: 0.3008 - val_accuracy: 0.9413
# Epoch 17/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2908 - accuracy: 0.9430 - val_loss: 0.2962 - val_accuracy: 0.9427
# Epoch 18/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2829 - accuracy: 0.9450 - val_loss: 0.2883 - val_accuracy: 0.9435
# Epoch 19/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2761 - accuracy: 0.9464 - val_loss: 0.2859 - val_accuracy: 0.9430
# Epoch 20/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2691 - accuracy: 0.9475 - val_loss: 0.2778 - val_accuracy: 0.9448
# Epoch 21/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2633 - accuracy: 0.9484 - val_loss: 0.2770 - val_accuracy: 0.9437
# Epoch 22/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2573 - accuracy: 0.9499 - val_loss: 0.2759 - val_accuracy: 0.9439
# Epoch 23/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2519 - accuracy: 0.9504 - val_loss: 0.2661 - val_accuracy: 0.9478
# Epoch 24/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2464 - accuracy: 0.9514 - val_loss: 0.2658 - val_accuracy: 0.9477
# Epoch 25/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2421 - accuracy: 0.9521 - val_loss: 0.2619 - val_accuracy: 0.9460
# Epoch 26/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2382 - accuracy: 0.9530 - val_loss: 0.2546 - val_accuracy: 0.9485
# Epoch 27/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2345 - accuracy: 0.9532 - val_loss: 0.2607 - val_accuracy: 0.9465
# Epoch 28/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2301 - accuracy: 0.9541 - val_loss: 0.2510 - val_accuracy: 0.9488
# Epoch 29/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2260 - accuracy: 0.9547 - val_loss: 0.2553 - val_accuracy: 0.9463
# Epoch 30/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2227 - accuracy: 0.9558 - val_loss: 0.2484 - val_accuracy: 0.9467
# Epoch 31/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2192 - accuracy: 0.9567 - val_loss: 0.2435 - val_accuracy: 0.9509
# Epoch 32/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2161 - accuracy: 0.9568 - val_loss: 0.2508 - val_accuracy: 0.9464
# Epoch 33/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2123 - accuracy: 0.9570 - val_loss: 0.2415 - val_accuracy: 0.9494
# Epoch 34/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2102 - accuracy: 0.9572 - val_loss: 0.2374 - val_accuracy: 0.9515
# Epoch 35/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2075 - accuracy: 0.9586 - val_loss: 0.2341 - val_accuracy: 0.9516
# Epoch 36/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2048 - accuracy: 0.9580 - val_loss: 0.2340 - val_accuracy: 0.9506
# Epoch 37/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2018 - accuracy: 0.9590 - val_loss: 0.2358 - val_accuracy: 0.9507
# Epoch 38/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2001 - accuracy: 0.9595 - val_loss: 0.2337 - val_accuracy: 0.9499
# Epoch 39/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1982 - accuracy: 0.9600 - val_loss: 0.2325 - val_accuracy: 0.9516
# Epoch 40/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1956 - accuracy: 0.9597 - val_loss: 0.2269 - val_accuracy: 0.9535
# Epoch 41/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1940 - accuracy: 0.9605 - val_loss: 0.2325 - val_accuracy: 0.9513
# Epoch 42/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1910 - accuracy: 0.9611 - val_loss: 0.2353 - val_accuracy: 0.9478
# Epoch 43/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1886 - accuracy: 0.9610 - val_loss: 0.2255 - val_accuracy: 0.9507
# Epoch 44/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1885 - accuracy: 0.9613 - val_loss: 0.2250 - val_accuracy: 0.9524
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1847 - accuracy: 0.9626 - val_loss: 0.2330 - val_accuracy: 0.9477
# Epoch 46/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1844 - accuracy: 0.9619 - val_loss: 0.2296 - val_accuracy: 0.9497
# Epoch 47/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1818 - accuracy: 0.9625 - val_loss: 0.2239 - val_accuracy: 0.9507
# Epoch 48/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1810 - accuracy: 0.9623 - val_loss: 0.2195 - val_accuracy: 0.9528
# Epoch 49/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1795 - accuracy: 0.9626 - val_loss: 0.2228 - val_accuracy: 0.9505
# Epoch 50/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1767 - accuracy: 0.9640 - val_loss: 0.2175 - val_accuracy: 0.9542

# %% [markdown]
# Puede verse que al aplicar la regularización, se consigue un menor sobreajuste en el modelo y una mejor convergencia. Por su parte, la bondad de ajuste en la muestra de test sigue siendo superior al modelo que se ha tomado como base.

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %%
loss_test, acc_test = model_2.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2202 - accuracy: 0.9512

# %% [markdown]
# #### 2.2.3 Uso de la parada temprana
#
# Para esta propuesta, se emplea la parada temprana durante el proceso de entrenamiento de la arquitectura del punto 2.2.1.

# %%
# SGD - modificación de tasa de aprendizaje y momento
own_sgd=tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)

# definición del callback - parada temprana 
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# Como puede verse, también han sido modificados los parámetros por defecto del compilador (lr=0.03 y momento=0.9). Por su parte, el entrenamiento del modelo parará en el momento en que la pérdida de validación aumente durante cinco épocas.
#
# Se vuelve a defininir la arquitectura y se realiza el proceso de entrenamiento:

# %%
model_1 = tf.keras.models.Sequential()
model_1.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

model_1.compile(optimizer=own_sgd, 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_1.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    callbacks = callback,
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.8506 - accuracy: 0.7182 - val_loss: 0.3694 - val_accuracy: 0.8929
# Epoch 2/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3470 - accuracy: 0.9001 - val_loss: 0.3252 - val_accuracy: 0.9032
# Epoch 3/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2811 - accuracy: 0.9181 - val_loss: 0.2620 - val_accuracy: 0.9217
# Epoch 4/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2449 - accuracy: 0.9276 - val_loss: 0.2622 - val_accuracy: 0.9243
# Epoch 5/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2224 - accuracy: 0.9338 - val_loss: 0.2106 - val_accuracy: 0.9371
# Epoch 6/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2063 - accuracy: 0.9380 - val_loss: 0.2196 - val_accuracy: 0.9347
# Epoch 7/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1884 - accuracy: 0.9442 - val_loss: 0.1935 - val_accuracy: 0.9461
# Epoch 8/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1853 - accuracy: 0.9459 - val_loss: 0.2013 - val_accuracy: 0.9438
# Epoch 9/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1707 - accuracy: 0.9499 - val_loss: 0.2038 - val_accuracy: 0.9413
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1686 - accuracy: 0.9504 - val_loss: 0.2032 - val_accuracy: 0.9438
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1664 - accuracy: 0.9499 - val_loss: 0.1983 - val_accuracy: 0.9433
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1595 - accuracy: 0.9531 - val_loss: 0.2235 - val_accuracy: 0.9400

# %% [markdown]
# Terminado el entrenamiento, se visualiza el proceso hasta la parada temprana.

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %%
loss_test, acc_test = model_1.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2392 - accuracy: 0.9370

# %% [markdown]
# Se observa además que la bondad de ajuste del modelo es

# %% [markdown]
# #### 2.2.4 Guardar de modelos
#
# Tras explicar la creación de redes neuronales en *tf.keras*, se indica el proceso seguido para guardar modelos:

# %%
import joblib
model_path = '../models/model.joblib' # nombre para guardar el fichero (incluye directorio de carpeta)

# %%
joblib.dump(model_funcional, model_path) # guardar modelo
# Out:
# ['../models/model.joblib']

# %%
new_model = joblib.load("../models/model.joblib") # cargar el modelo previamente guardado

# %%
y_pred_funcional = model_funcional.predict(X_test)
y_pred_new_model = new_model.predict(X_test)

print(y_pred_funcional[0]) 
print(y_pred_new_model[0])
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# [2.0685949e-05 1.9291522e-09 4.9405706e-05 2.0563933e-03 5.9188994e-07
#  1.4180400e-05 3.1375988e-10 9.9748516e-01 1.4417150e-05 3.5919034e-04]
# [2.0685949e-05 1.9291522e-09 4.9405706e-05 2.0563933e-03 5.9188994e-07
#  1.4180400e-05 3.1375988e-10 9.9748516e-01 1.4417150e-05 3.5919034e-04]

# %% [markdown]
# A pesar de que se recomienda guardar el modelo de la forma anterior, también nos puede interesar únicamente guardar la arquitectura o los pesos de la red. Para guardar la arquitectura se emplea la siguiente sintaxis:

# %%
config = model_funcional.get_config() # obtención de la configuración del modelo
reinitialized_model = tf.keras.Model.from_config(config) 

y_pred_funcional = model_funcional.predict(X_test)
y_pred_reinitialized_model = reinitialized_model.predict(X_test)

print(y_pred_funcional[0]) 
print(y_pred_reinitialized_model[0])
# Out:
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
# [2.0685949e-05 1.9291522e-09 4.9405706e-05 2.0563933e-03 5.9188994e-07
#  1.4180400e-05 3.1375988e-10 9.9748516e-01 1.4417150e-05 3.5919034e-04]
# [0.01609934 0.17043017 0.06939992 0.10031038 0.04084643 0.07354143
#  0.07205831 0.12993163 0.13301897 0.1943634 ]

# %% [markdown]
# Como puede verse, como solo se ha guardado la arquitectura del modelo, las predicciones ahora son diferentes pues no se dispone de la información aprendida previamente durante el entrenamiento. Por último, con el siguiente código se guardan los pesos de la red.

# %%
weights = model_funcional.get_weights() # Recupera el estado del modelo (matriz de pesos en formato lista - array de numpy)

# %% [markdown]
# Para acceder a los pesos de cada capa se accede al elemento de la lista.

# %%
weights[0]  # pesos de la primera capa
# Out:
# array([[-0.00370155,  0.05303529,  0.019025  , ...,  0.03872482,
#         -0.03549255,  0.04828976],
#        [-0.05630091, -0.08604092, -0.03674991, ...,  0.06973587,
#          0.06683509,  0.01024305],
#        [ 0.05255115, -0.03174344, -0.00161762, ...,  0.07085414,
#          0.00036997, -0.08028594],
#        ...,
#        [ 0.08240126,  0.06692454, -0.02313185, ..., -0.05432935,
#         -0.03583526,  0.08121967],
#        [-0.02907873, -0.08274835, -0.05451505, ...,  0.06975886,
#          0.04168573, -0.01031784],
#        [-0.04201533,  0.0628777 , -0.03397524, ...,  0.06793448,
#          0.00909244,  0.00627495]], dtype=float32)
