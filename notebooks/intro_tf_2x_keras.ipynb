# %% [markdown]
# # INTRODUCCIÓN A TENSORFLOW 2.X - KERAS

# %% [markdown]
# ## 1. Tensorflow y Keras
#
# **Tensorflow** es una potente librería de código abierto desarrollada por Google (febrero 2017, v1.0) para la creación de redes neuronales profundas de manera completa. Existen otros paquetes de software libre como *Pytorch* o *MxNet*. que son también utilizados en Deep Learning; si bien, su popularidad entre la comunidad de científicos de datos es, a día de hoy, inferior a Tensorflow.
#
# Entre las principales ventajas de utilizar Tensorflow se encuentran:
# - Trabaja con lenguajes como Python, R, Java, C++ y Go
# - Keras viene integrado en Tensorflow 2.0
# - Permite la realización de cálculos en paralelo lo que reduce el tiempo de ejecución
# - Permite el desarrollo de modelos y su puesta en producción de forma ágil
# - Actualmente dispone de una comunidad de soporte mucho más avanzada que el resto de frameworks
#
# La llamada al módulo de Keras en la versión 2.0 (o superior) de Tensorflow tiene lugar mediante *tf.keras*; si bien, destacar que existen ligeras diferencias entre el módulo soportado y la propia librería. Por todo ello, siempre que se trabaje con Tensorflow se recomienda emplear el módulo *tf.keras* pues que permite una total integración.
#
# Con *tf.keras* se pueden modelos mediante diferentes métodos:
# - **Secuencial:** adecuado para una pila simple de capas (cada una de ellas tiene exactamente un tensor de entrada y otro de salida). Es el método más sencillo
# - **Funcional:** permite crear modelos de forma más dinámica que mediante el método *Sequential*. De gran utilidad para desarrollar modelos con capas compartidas, multiples entradas-salidas o de topología no lineal. Es el más utilizado en la industria pues, prácticamente, todos los proyectos de Deep Learning pueden definirse siguiendo este método
# - **Modular:** permite la generación de modelos de redes neuonales profundas muy específicos. Suele ser utilizado en entornos de investigación académica

# %%
import tensorflow as tf
print('Version:', tf.__version__)
# Out:
# Version: 2.12.0

# %% [markdown]
# ## 1. Primera Red Neuronal en tf 2.x
#
# ### 1.1 Entrenamiento de una red neuronal Simple
#
# Para la creación de nuestra primera red neuronal se va a emplear la base de datos MNIST. Esta base de datos, de las más importantes a nivel aprendizaje supervisado, es un conjunto de 70.000 imágenes en escala de grises de digitos escritos a mano.
#
# Destacar que, por sencillez, se va a diseñar una arquitectura de Deep Learning compuesta por redes densamente conectadas. Por su parte, para ilustrar los dos primeros métodos de *tf.keras*, la arquitectura de la red será creada siguiendo tanto el método secuencial como el funcional.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.datasets import mnist 


(X_train, Y_train), (X_test, Y_test) = mnist.load_data() # carga de datos (train y test)

# %% [markdown]
# Como puede verse, se tiene como tensor de entrada el número de imágenes y la dimensión (alto-ancho)

# %%
print('X - train:', X_train.shape)
print('X - test:', X_test.shape)
# Out:
# X - train: (60000, 28, 28)
# X - test: (10000, 28, 28)

# %% [markdown]
# Sin embargo, cuando se trabaja con redes densamente conectadas, es necesario redefinir el tamaño de la entrada a una matriz de *nxm* (donde n es el número de muestras y m es el número de píxeles de la imagen).

# %%
remodelado = X_train.shape[1]*X_train.shape[2] # 784 neuronas de entrada -> 28*28

# redifinición de los datos de entrada a la red (train y test)
X_train = X_train.reshape(X_train.shape[0], remodelado)
X_test = X_test.reshape(X_test.shape[0], remodelado)

# %% [markdown]
# Se observa que el tamaño ha variado pero el número de muestras se mantiene.

# %%
print('X - train:', X_train.shape)
print('X - test:', X_test.shape)
# Out:
# X - train: (60000, 784)
# X - test: (10000, 784)

# %% [markdown]
# Adicionalmente, para mejorar el aprendizaje de la red, los valores asociados con cada pixel son normalizados en función de la intensidad (normalización entre 0 y 1). Para ello, se dividen los datos de entrada entre 255 (color blanco en la escala RGB).

# %%
X_train = X_train/255
X_test = X_test/255

# %% [markdown]
# Como todo aprendizaje supervisado, el target es un vector de etiquetas. En este caso, se tiene un problema de clasificación multinivel (10 clases, cada una un dígito). Por tanto, se convierte a variable dummy las etiquetas.

# %%
num_clase = 10

Y_train = tf.keras.utils.to_categorical(Y_train,num_clase)
Y_test = tf.keras.utils.to_categorical(Y_test,num_clase)

print('Y - train:', Y_train.shape)
print('Y - test:', Y_test.shape)
# Out:
# Y - train: (60000, 10)
# Y - test: (10000, 10)

# %% [markdown]
# Una vez realizado el procesado de los datos de entrada se procede con la definición de la arquitectura de la red. Para ello, hay que tener en cuenta, al menos, las siguientes consideraciones:
# - Datos de entrada: 784 neuronas en la capa de entrada a la red
# - Datos de salida: 10 neuronas salida de la red (activación softmax para tener una probabilidad entre 0 y 1 para cada categoría)
# - Capas intermedias: número de capas y neuronas que consideremos apropiado según el proyecto (incluyendo la elección de la función de activación)
#
# En este caso, se diseña una red neuronal con una única capa intermedia con 16 neuronas y función de activación lineal.
#
# #### 1.1.1 Arquitectura de la red
#
# Como se ha comentado inicialmente, se crea la red siguiendo los métodos *Sequential* y *Funcional* de *tf.keras*:

# %% [markdown]
# **Sequential**

# %%
# definición del modelo secuencial
model_sequential = tf.keras.models.Sequential()
# capa de entrada e intermedia
model_sequential.add(tf.keras.layers.Dense(units=16, activation='linear', input_shape=(remodelado,)))
# capa de salida: no se necesita definir su capa de entrada al ser un modelo secuencial
model_sequential.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# En la siguiente tabla se presenta un resumen de las capas y parámetros de la red.

# %%
model_sequential.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 16)                12560
#
#  dense_1 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se observa que que la red tiene 3 capas (entrada, oculta y salida) y un total de 12.730 parámetros (los cuales son todos entrenables). Asimismo, los parámetros por capa son:
# - Oculta: entrada_nnet * neuronas_hidden + bias_hidden = 784 * 16 + 16
# - Salida: entrada_hidden * neuronas_out + bias_out = 16 * 10 + 10

# %% [markdown]
# **Funcional**

# %%
# capa de entrada
inputs = tf.keras.Input(shape=(remodelado,))
# capa oculta (a la que se le indica cuál es la capa anterior)
hidden = tf.keras.layers.Dense(units=16, activation='linear')(inputs)
# capa de salida (a la que se le indica cuál es la capa anterior)
out = tf.keras.layers.Dense(units=num_clase, activation='softmax')(hidden)
# definición del modelo funcional
model_funcional = tf.keras.Model(inputs=inputs, outputs=out)

# %%
model_funcional.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 784)]             0
#
#  dense_2 (Dense)             (None, 16)                12560
#
#  dense_3 (Dense)             (None, 10)                170
#
# =================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Como puede verse, mediante el método funcional se dispone del mismo número de parámetros (y capas) que a partir del secuencial. Notar aquí la diferente forma de codificar el mismo diseño de red neuronal, esto es, mientras que en el método *Sequential* la capa de entrada se define en la capa intermedia, el método *Funcional* requiere de su definición como input.
#
# #### 1.1.2 Proceso de entranamiento
#
# Una vez diseñada la arquitectura de nuestra primera red neuronal profunda, es momento de la compilación y el entrenamiento de la misma. El proceso de entrenamiento de una red neuronal es un proceso iterativo que consiste en minimizar el valor de una **función objetivo** a partir de un algoritmo de optimización, típicamente el **Gradiente Descendiente** (o modificaciones de éste). Así, durante las diferentes etapas del entrenamiento, los valores de los pesos de la red neuronal se van actualizando. Por último, se disponde de una métrica para evaluar la bondad de ajuste del modelo.
#
# - **Función objetivo:** también conocida como *función de pérdida*, es una función que debe ser continua y derivable y es específica proyecto en cuestión. En este caso, al ser un problema de clasificación multiclase, se emplea *categorical_crossentropy*
# - **Optimizador:** existen diferentes algoritmos para minimizar el error de la *función de pérdida*. El más conocido es el *Gradiente Descendente Estocástico*; si bien, más adelante veremos otros que suelen mejorar las estimaciones de la red
# - **Métrica:** cualquier métrica que permite evaluar el error del modelo (accuracy, error cuadrático medio, área bajo la curva roc, etc.)
#
# Adicionalmente, destacar que **Tensorflow** permite definir tanto métricas como funciones objetivo propias del usuario; si bien, ese tipo de casuísticas solo se suele darse en proyectos de investigación.
#
# Así, se procede a compilar la red definida con el método funcional:

# %%
model_funcional.compile(optimizer='SGD', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

# %% [markdown]
# Por último, se lleva a cabo el entrenamiento de la red. Para ello, al ser un proceso iterativo se debe tener en cuenta los siguientes conceptos:
# - Épocas: número de veces que el modelo es expuesto al entrenamiento. En cada iteración, se trata de minimizar la función de pérdida, siendo actualizados los pesos de la red por el optimizador.
# - Lote: número de instancias utilizadas en el entrenamiento antes de que el optimizador actualize los pesos de la red
#
# A la hora de realizar el entrenamiento, es importante reservar una muestra de los datos de entrenamiento para su validación

# %%
tf.random.set_seed(123)

epoca = 50
lote = 128
validacion = 0.2 

history = model_funcional.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 6ms/step - loss: 1.2753 - accuracy: 0.6533 - val_loss: 0.7532 - val_accuracy: 0.8260
# Epoch 2/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.6599 - accuracy: 0.8342 - val_loss: 0.5310 - val_accuracy: 0.8619
# Epoch 3/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5215 - accuracy: 0.8620 - val_loss: 0.4510 - val_accuracy: 0.8765
# Epoch 4/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4595 - accuracy: 0.8751 - val_loss: 0.4088 - val_accuracy: 0.8870
# Epoch 5/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4237 - accuracy: 0.8824 - val_loss: 0.3837 - val_accuracy: 0.8932
# Epoch 6/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4003 - accuracy: 0.8880 - val_loss: 0.3653 - val_accuracy: 0.8979
# Epoch 7/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3834 - accuracy: 0.8927 - val_loss: 0.3528 - val_accuracy: 0.8997
# Epoch 8/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3706 - accuracy: 0.8952 - val_loss: 0.3428 - val_accuracy: 0.9022
# Epoch 9/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3605 - accuracy: 0.8986 - val_loss: 0.3350 - val_accuracy: 0.9049
# Epoch 10/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3524 - accuracy: 0.9004 - val_loss: 0.3281 - val_accuracy: 0.9067
# Epoch 11/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3453 - accuracy: 0.9025 - val_loss: 0.3231 - val_accuracy: 0.9080
# Epoch 12/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3395 - accuracy: 0.9040 - val_loss: 0.3189 - val_accuracy: 0.9103
# Epoch 13/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3345 - accuracy: 0.9050 - val_loss: 0.3144 - val_accuracy: 0.9113
# Epoch 14/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3300 - accuracy: 0.9061 - val_loss: 0.3109 - val_accuracy: 0.9123
# Epoch 15/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3261 - accuracy: 0.9073 - val_loss: 0.3079 - val_accuracy: 0.9137
# Epoch 16/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3227 - accuracy: 0.9080 - val_loss: 0.3049 - val_accuracy: 0.9145
# Epoch 17/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3195 - accuracy: 0.9093 - val_loss: 0.3029 - val_accuracy: 0.9145
# Epoch 18/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3166 - accuracy: 0.9108 - val_loss: 0.3004 - val_accuracy: 0.9154
# Epoch 19/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3140 - accuracy: 0.9109 - val_loss: 0.2990 - val_accuracy: 0.9171
# Epoch 20/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3117 - accuracy: 0.9122 - val_loss: 0.2971 - val_accuracy: 0.9164
# Epoch 21/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3095 - accuracy: 0.9125 - val_loss: 0.2953 - val_accuracy: 0.9173
# Epoch 22/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3074 - accuracy: 0.9137 - val_loss: 0.2937 - val_accuracy: 0.9174
# Epoch 23/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3055 - accuracy: 0.9137 - val_loss: 0.2924 - val_accuracy: 0.9182
# Epoch 24/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3037 - accuracy: 0.9140 - val_loss: 0.2912 - val_accuracy: 0.9174
# Epoch 25/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.3021 - accuracy: 0.9148 - val_loss: 0.2907 - val_accuracy: 0.9186
# Epoch 26/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3005 - accuracy: 0.9149 - val_loss: 0.2889 - val_accuracy: 0.9183
# Epoch 27/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2992 - accuracy: 0.9158 - val_loss: 0.2877 - val_accuracy: 0.9190
# Epoch 28/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2976 - accuracy: 0.9156 - val_loss: 0.2870 - val_accuracy: 0.9196
# Epoch 29/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2965 - accuracy: 0.9158 - val_loss: 0.2865 - val_accuracy: 0.9201
# Epoch 30/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2953 - accuracy: 0.9166 - val_loss: 0.2850 - val_accuracy: 0.9206
# Epoch 31/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2939 - accuracy: 0.9170 - val_loss: 0.2842 - val_accuracy: 0.9205
# Epoch 32/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2928 - accuracy: 0.9171 - val_loss: 0.2836 - val_accuracy: 0.9207
# Epoch 33/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2918 - accuracy: 0.9181 - val_loss: 0.2831 - val_accuracy: 0.9200
# Epoch 34/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2906 - accuracy: 0.9180 - val_loss: 0.2825 - val_accuracy: 0.9212
# Epoch 35/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2897 - accuracy: 0.9179 - val_loss: 0.2819 - val_accuracy: 0.9213
# Epoch 36/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2888 - accuracy: 0.9179 - val_loss: 0.2815 - val_accuracy: 0.9209
# Epoch 37/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2879 - accuracy: 0.9189 - val_loss: 0.2806 - val_accuracy: 0.9209
# Epoch 38/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2870 - accuracy: 0.9192 - val_loss: 0.2801 - val_accuracy: 0.9209
# Epoch 39/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2861 - accuracy: 0.9194 - val_loss: 0.2796 - val_accuracy: 0.9220
# Epoch 40/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2854 - accuracy: 0.9190 - val_loss: 0.2793 - val_accuracy: 0.9218
# Epoch 41/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2846 - accuracy: 0.9195 - val_loss: 0.2786 - val_accuracy: 0.9231
# Epoch 42/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2836 - accuracy: 0.9202 - val_loss: 0.2781 - val_accuracy: 0.9217
# Epoch 43/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2831 - accuracy: 0.9200 - val_loss: 0.2784 - val_accuracy: 0.9216
# Epoch 44/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2823 - accuracy: 0.9201 - val_loss: 0.2776 - val_accuracy: 0.9224
# Epoch 45/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2815 - accuracy: 0.9201 - val_loss: 0.2771 - val_accuracy: 0.9226
# Epoch 46/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2810 - accuracy: 0.9207 - val_loss: 0.2768 - val_accuracy: 0.9229
# Epoch 47/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2803 - accuracy: 0.9209 - val_loss: 0.2763 - val_accuracy: 0.9224
# Epoch 48/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2796 - accuracy: 0.9208 - val_loss: 0.2762 - val_accuracy: 0.9232
# Epoch 49/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2790 - accuracy: 0.9209 - val_loss: 0.2755 - val_accuracy: 0.9230
# Epoch 50/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2784 - accuracy: 0.9215 - val_loss: 0.2754 - val_accuracy: 0.9227

# %% [markdown]
# #### 1.1.3 Análisis de resultados
# Como puede verse, se tiene un ajuste superior al 90% en entrenamiento y validación. Veamos gráficamente el proceso de entrenamiento (loss y accuracy):

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# Si nos fijamos en la curvas de pérdida, la de entrenamiento está por encima de la de validación. Esto hecho, aunque posible, pero no suele ser usual ya que, generalmente, la red se ajusta mejor a los datos de entrenamiento.
# Adicionalmente, es importante destacar que, tras 50 épocas el proceso de convergencia de la red no ha llegado a su fin (curvas de loss y accuracy no son completamente planas).
#
# Por último, se evalua el desempeño del modelo en la muestra de test.

# %%
loss_test, acc_test = model_funcional.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2785 - accuracy: 0.9216

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

Y_test_pred = np.argmax(model_funcional.predict(X_test), axis=1) # predicción de la muestra test - en formato etiqueta
Y_test_label = np.argmax(Y_test, axis=1) # muestra test en formato etiqueta
sns.heatmap(confusion_matrix(Y_test_pred, Y_test_label), annot = True, fmt='.0f') # matriz de confusión
plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Como puede verse, el accuracy en la muestra de test es similar al obtenido en la muestra de entrenamiento y validación. Asimismo, se observa en matriz de confusión como la clasificación de los diez dígitos tiene un elevado grado de acierto.

# %% [markdown]
# ## 2. Mejorando la red neuronal
#
# Se ha visto que la red neuronal anterior tiene una buena bondad de ajuste (por encima del 90%) y un número de parámetros un 20% inferior a los datos de partida. A pesar de que podríamos decir que es un muy buen modelo, es posible mejorar el modelo empleando:
# - Más capas ocultas: manteniendo siempre una proporcionalidad entre parámetros/datos y evitando el sobreentrenamiento
# - Funciones de activación: probaremos la función *ReLu* (la más apropiada para modelos con múltiples capas ocultas)
# - Inicialización de los pesos: suele emplearse la inialización de Xavier/Glorot (por defecto en *tf.keras*) pero hay otras como inicialización aleatoria, normalizada, Lecun, etc.
# - Optimizadores: Adam (utilizado en la mayor parte de los problemas de deep learning), AdaGrad, RMSProp, etc.
#
# Por contra, muchas veces al entrenar el modelo se cae en el sobreajuste de los datos. Para evitarlo, se emplean técnicas de parada temprana o de regularización. Las técnicas de regularización más comunes son:
# - Dropout: eliminación al azar de algunas de las neuronas de la red en el entrenamiento por lotes (para la predicción se usan todas las neuronas)
# - L1, L2, Elastic Net: modificación de la función de pérdida en función de un factor dependiendo de los pesos de la red (norma, cuadrado o combianción de las dos, respectivamente)
#
# Finalmente, la búsqueda de los parámetros más adecuados para el problema es un hecho diferenciador a la hora de encontrar la máxima bondad de ajuste. Si se tiene cierto conocimiento sobre el ámbito del proyecto puede ser de gran utilidad una búsqueda "fina" de forma aleatoria, pero se recomienda que el usuario monitoriza la modificación de los parámetros:
# - Arquitectura de la red (número de capas, neuronas o función de activación)
# - Número de épocas o tamaño del batch
# - Diferentes técnicas de regularización
#
# Una vez comentados los aspectos teóricos, se procede a realizar diferentes propuestas para mejorar el modelo anterior que lo utilizaremos como base; es decir, si no se mejora la bondad de ajuste serán rechazadas las diferentes propuestas.
#
# ### 2.1 Propuestas de mejora

# %% [markdown]
# #### 2.1.1. Aumento de capas ocultas y optimizador de Adam
#
# Se incorporan dos capas ocultas de 8 neuronas y función de activación *ReLu* (salvo en la capa de salida). Asimismo, se empleará *Adam* como optimizador.

# %%
# dropout=0.2

model_1 = tf.keras.models.Sequential()
model_1.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
# model_1.add(tf.keras.layers.Dropout(dropout))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# Como puede verse en la tabla resumen, el número de parámetros ha aumentado ligeramente al incluir dos capas intermedias más.

# %%
model_1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 16)                12560
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 8)                 72
#
#  dense_7 (Dense)             (None, 10)                90
#
# =================================================================
# Total params: 12,858
# Trainable params: 12,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se compila y se hace el entrenamiento de este nuevo modelo.

# %%
model_1.compile(optimizer='adam', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_1.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 4s 6ms/step - loss: 1.0637 - accuracy: 0.6529 - val_loss: 0.5492 - val_accuracy: 0.8485
# Epoch 2/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5050 - accuracy: 0.8578 - val_loss: 0.4264 - val_accuracy: 0.8832
# Epoch 3/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4115 - accuracy: 0.8871 - val_loss: 0.3698 - val_accuracy: 0.8963
# Epoch 4/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3595 - accuracy: 0.9005 - val_loss: 0.3307 - val_accuracy: 0.9082
# Epoch 5/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3209 - accuracy: 0.9110 - val_loss: 0.3150 - val_accuracy: 0.9136
# Epoch 6/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2929 - accuracy: 0.9196 - val_loss: 0.2904 - val_accuracy: 0.9202
# Epoch 7/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2690 - accuracy: 0.9247 - val_loss: 0.2677 - val_accuracy: 0.9252
# Epoch 8/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2500 - accuracy: 0.9311 - val_loss: 0.2548 - val_accuracy: 0.9273
# Epoch 9/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2357 - accuracy: 0.9346 - val_loss: 0.2480 - val_accuracy: 0.9308
# Epoch 10/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2245 - accuracy: 0.9374 - val_loss: 0.2385 - val_accuracy: 0.9320
# Epoch 11/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2129 - accuracy: 0.9410 - val_loss: 0.2263 - val_accuracy: 0.9357
# Epoch 12/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2034 - accuracy: 0.9433 - val_loss: 0.2222 - val_accuracy: 0.9370
# Epoch 13/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1951 - accuracy: 0.9445 - val_loss: 0.2171 - val_accuracy: 0.9399
# Epoch 14/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1865 - accuracy: 0.9466 - val_loss: 0.2119 - val_accuracy: 0.9421
# Epoch 15/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9490 - val_loss: 0.2102 - val_accuracy: 0.9401
# Epoch 16/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1745 - accuracy: 0.9500 - val_loss: 0.2075 - val_accuracy: 0.9413
# Epoch 17/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1696 - accuracy: 0.9500 - val_loss: 0.2049 - val_accuracy: 0.9439
# Epoch 18/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1633 - accuracy: 0.9536 - val_loss: 0.1987 - val_accuracy: 0.9430
# Epoch 19/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1611 - accuracy: 0.9535 - val_loss: 0.1997 - val_accuracy: 0.9417
# Epoch 20/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1559 - accuracy: 0.9549 - val_loss: 0.2021 - val_accuracy: 0.9427
# Epoch 21/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1528 - accuracy: 0.9554 - val_loss: 0.1987 - val_accuracy: 0.9436
# Epoch 22/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1484 - accuracy: 0.9567 - val_loss: 0.1996 - val_accuracy: 0.9432
# Epoch 23/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1448 - accuracy: 0.9578 - val_loss: 0.1955 - val_accuracy: 0.9442
# Epoch 24/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1424 - accuracy: 0.9585 - val_loss: 0.1963 - val_accuracy: 0.9453
# Epoch 25/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1397 - accuracy: 0.9593 - val_loss: 0.1992 - val_accuracy: 0.9423
# Epoch 26/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1374 - accuracy: 0.9596 - val_loss: 0.1939 - val_accuracy: 0.9452
# Epoch 27/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1346 - accuracy: 0.9612 - val_loss: 0.1917 - val_accuracy: 0.9453
# Epoch 28/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1314 - accuracy: 0.9613 - val_loss: 0.1917 - val_accuracy: 0.9469
# Epoch 29/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1285 - accuracy: 0.9624 - val_loss: 0.1952 - val_accuracy: 0.9465
# Epoch 30/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1279 - accuracy: 0.9625 - val_loss: 0.2004 - val_accuracy: 0.9444
# Epoch 31/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1256 - accuracy: 0.9632 - val_loss: 0.1929 - val_accuracy: 0.9468
# Epoch 32/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1243 - accuracy: 0.9635 - val_loss: 0.1940 - val_accuracy: 0.9467
# Epoch 33/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1206 - accuracy: 0.9645 - val_loss: 0.1928 - val_accuracy: 0.9480
# Epoch 34/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1214 - accuracy: 0.9647 - val_loss: 0.1979 - val_accuracy: 0.9456
# Epoch 35/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1177 - accuracy: 0.9654 - val_loss: 0.1916 - val_accuracy: 0.9473
# Epoch 36/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1160 - accuracy: 0.9660 - val_loss: 0.1952 - val_accuracy: 0.9463
# Epoch 37/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1147 - accuracy: 0.9658 - val_loss: 0.1976 - val_accuracy: 0.9452
# Epoch 38/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1140 - accuracy: 0.9669 - val_loss: 0.1939 - val_accuracy: 0.9483
# Epoch 39/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1118 - accuracy: 0.9666 - val_loss: 0.1919 - val_accuracy: 0.9474
# Epoch 40/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1103 - accuracy: 0.9671 - val_loss: 0.1951 - val_accuracy: 0.9488
# Epoch 41/50
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9674 - val_loss: 0.1983 - val_accuracy: 0.9473
# Epoch 42/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1074 - accuracy: 0.9680 - val_loss: 0.2007 - val_accuracy: 0.9465
# Epoch 43/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1071 - accuracy: 0.9680 - val_loss: 0.1949 - val_accuracy: 0.9504
# Epoch 44/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1052 - accuracy: 0.9684 - val_loss: 0.2033 - val_accuracy: 0.9471
# Epoch 45/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1024 - accuracy: 0.9696 - val_loss: 0.2112 - val_accuracy: 0.9438
# Epoch 46/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1008 - accuracy: 0.9699 - val_loss: 0.1966 - val_accuracy: 0.9481
# Epoch 47/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1010 - accuracy: 0.9696 - val_loss: 0.2003 - val_accuracy: 0.9476
# Epoch 48/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0992 - accuracy: 0.9703 - val_loss: 0.1981 - val_accuracy: 0.9486
# Epoch 49/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0985 - accuracy: 0.9707 - val_loss: 0.2054 - val_accuracy: 0.9460
# Epoch 50/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0981 - accuracy: 0.9701 - val_loss: 0.2083 - val_accuracy: 0.9465

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %% [markdown]
# Como puede verse, la red empieza a sobreajustar desde las primeras épocas pero, a la vista del resultado en la muestra de test, el modelo tiene una alta capacidad predictiva.

# %%
loss_test, acc_test = model_1.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2236 - accuracy: 0.9454

# %% [markdown]
# Se deja al alumno la creación de un modelo con una capa de dropout (descomentar las líneas de código de la arquitectura).

# %% [markdown]
# #### 2.1.2 Regularización de los pesos de la red
#
# Se incorpora la regularización L2 a las capas de 8 neuronas. El valor de la regularización será de 0.01.

# %%
l2_value=0.01

model_2 = tf.keras.models.Sequential()
model_2.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_2.add(tf.keras.layers.Dense(units=8, 
                                 activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(l2_value)))
model_2.add(tf.keras.layers.Dense(units=8, 
                                 activation='relu',
                                 kernel_regularizer=tf.keras.regularizers.l2(l2_value)))
model_2.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

# %% [markdown]
# Puede verse que el número de capas y los parámetros del modelo son los mismos que en la primera propuesta.

# %%
model_2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 16)                12560
#
#  dense_9 (Dense)             (None, 8)                 136
#
#  dense_10 (Dense)            (None, 8)                 72
#
#  dense_11 (Dense)            (None, 10)                90
#
# =================================================================
# Total params: 12,858
# Trainable params: 12,858
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Se compila y se hace el entrenamiento de esta nueva propuesta. En este caso, también se emplea *Adam* como optimizador.

# %%
model_2.compile(optimizer='adam', 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_2.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 4s 5ms/step - loss: 1.2567 - accuracy: 0.6635 - val_loss: 0.7143 - val_accuracy: 0.8581
# Epoch 2/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.6582 - accuracy: 0.8695 - val_loss: 0.5614 - val_accuracy: 0.8924
# Epoch 3/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.5510 - accuracy: 0.8957 - val_loss: 0.4938 - val_accuracy: 0.9062
# Epoch 4/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4981 - accuracy: 0.9057 - val_loss: 0.4574 - val_accuracy: 0.9113
# Epoch 5/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4615 - accuracy: 0.9140 - val_loss: 0.4348 - val_accuracy: 0.9198
# Epoch 6/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4358 - accuracy: 0.9164 - val_loss: 0.4142 - val_accuracy: 0.9222
# Epoch 7/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.4131 - accuracy: 0.9220 - val_loss: 0.3935 - val_accuracy: 0.9261
# Epoch 8/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3932 - accuracy: 0.9255 - val_loss: 0.3803 - val_accuracy: 0.9285
# Epoch 9/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3778 - accuracy: 0.9287 - val_loss: 0.3643 - val_accuracy: 0.9309
# Epoch 10/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3634 - accuracy: 0.9300 - val_loss: 0.3549 - val_accuracy: 0.9328
# Epoch 11/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3508 - accuracy: 0.9332 - val_loss: 0.3481 - val_accuracy: 0.9309
# Epoch 12/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3412 - accuracy: 0.9345 - val_loss: 0.3394 - val_accuracy: 0.9342
# Epoch 13/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3304 - accuracy: 0.9360 - val_loss: 0.3304 - val_accuracy: 0.9358
# Epoch 14/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.3216 - accuracy: 0.9370 - val_loss: 0.3230 - val_accuracy: 0.9352
# Epoch 15/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3132 - accuracy: 0.9389 - val_loss: 0.3214 - val_accuracy: 0.9361
# Epoch 16/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.3063 - accuracy: 0.9391 - val_loss: 0.3134 - val_accuracy: 0.9387
# Epoch 17/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2990 - accuracy: 0.9404 - val_loss: 0.3059 - val_accuracy: 0.9378
# Epoch 18/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2924 - accuracy: 0.9419 - val_loss: 0.2982 - val_accuracy: 0.9401
# Epoch 19/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2872 - accuracy: 0.9420 - val_loss: 0.2968 - val_accuracy: 0.9408
# Epoch 20/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2815 - accuracy: 0.9439 - val_loss: 0.2931 - val_accuracy: 0.9402
# Epoch 21/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2766 - accuracy: 0.9438 - val_loss: 0.2914 - val_accuracy: 0.9415
# Epoch 22/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2723 - accuracy: 0.9459 - val_loss: 0.2890 - val_accuracy: 0.9400
# Epoch 23/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2681 - accuracy: 0.9460 - val_loss: 0.2815 - val_accuracy: 0.9433
# Epoch 24/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2635 - accuracy: 0.9469 - val_loss: 0.2825 - val_accuracy: 0.9402
# Epoch 25/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2602 - accuracy: 0.9470 - val_loss: 0.2813 - val_accuracy: 0.9379
# Epoch 26/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2558 - accuracy: 0.9484 - val_loss: 0.2741 - val_accuracy: 0.9425
# Epoch 27/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2528 - accuracy: 0.9481 - val_loss: 0.2728 - val_accuracy: 0.9409
# Epoch 28/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2489 - accuracy: 0.9492 - val_loss: 0.2676 - val_accuracy: 0.9431
# Epoch 29/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2445 - accuracy: 0.9497 - val_loss: 0.2720 - val_accuracy: 0.9424
# Epoch 30/50
# 375/375 [==============================] - 2s 5ms/step - loss: 0.2414 - accuracy: 0.9505 - val_loss: 0.2701 - val_accuracy: 0.9401
# Epoch 31/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2397 - accuracy: 0.9509 - val_loss: 0.2646 - val_accuracy: 0.9442
# Epoch 32/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2369 - accuracy: 0.9510 - val_loss: 0.2654 - val_accuracy: 0.9424
# Epoch 33/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2336 - accuracy: 0.9516 - val_loss: 0.2621 - val_accuracy: 0.9422
# Epoch 34/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2310 - accuracy: 0.9523 - val_loss: 0.2605 - val_accuracy: 0.9430
# Epoch 35/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2293 - accuracy: 0.9522 - val_loss: 0.2628 - val_accuracy: 0.9437
# Epoch 36/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2270 - accuracy: 0.9530 - val_loss: 0.2585 - val_accuracy: 0.9445
# Epoch 37/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2243 - accuracy: 0.9534 - val_loss: 0.2544 - val_accuracy: 0.9449
# Epoch 38/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2222 - accuracy: 0.9535 - val_loss: 0.2582 - val_accuracy: 0.9438
# Epoch 39/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2207 - accuracy: 0.9533 - val_loss: 0.2515 - val_accuracy: 0.9432
# Epoch 40/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2189 - accuracy: 0.9541 - val_loss: 0.2485 - val_accuracy: 0.9435
# Epoch 41/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2169 - accuracy: 0.9544 - val_loss: 0.2598 - val_accuracy: 0.9438
# Epoch 42/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2142 - accuracy: 0.9543 - val_loss: 0.2532 - val_accuracy: 0.9417
# Epoch 43/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2117 - accuracy: 0.9550 - val_loss: 0.2553 - val_accuracy: 0.9423
# Epoch 44/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2111 - accuracy: 0.9549 - val_loss: 0.2440 - val_accuracy: 0.9442
# Epoch 45/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2085 - accuracy: 0.9562 - val_loss: 0.2473 - val_accuracy: 0.9437
# Epoch 46/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2062 - accuracy: 0.9565 - val_loss: 0.2427 - val_accuracy: 0.9454
# Epoch 47/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2043 - accuracy: 0.9574 - val_loss: 0.2441 - val_accuracy: 0.9452
# Epoch 48/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2028 - accuracy: 0.9574 - val_loss: 0.2394 - val_accuracy: 0.9460
# Epoch 49/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2013 - accuracy: 0.9572 - val_loss: 0.2473 - val_accuracy: 0.9433
# Epoch 50/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1995 - accuracy: 0.9577 - val_loss: 0.2371 - val_accuracy: 0.9477

# %% [markdown]
# Puede verse que al aplicar la regularización, se consigue un menor sobreajuste en el modelo y una mejor convergencia. Por su parte, la bondad de ajuste en la muestra de test sigue siendo superior al modelo que se ha tomado como base.

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %%
loss_test, acc_test = model_2.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.2366 - accuracy: 0.9467

# %% [markdown]
# #### 2.2.3 Uso de la parada temprana
#
# Para esta propuesta, se emplea la parada temprana durante el proceso de entrenamiento de la arquitectura del punto 2.2.1.

# %%
# SGD - modificación de tasa de aprendizaje y momento
own_sgd=tf.keras.optimizers.SGD(learning_rate=0.02, momentum=0.9)

# definición del callback - parada temprana 
callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# Como puede verse, también han sido modificados los parámetros por defecto del compilador (lr=0.03 y momento=0.9). Por su parte, el entrenamiento del modelo parará en el momento en que la pérdida de validación aumente durante cinco épocas.
#
# Se vuelve a defininir la arquitectura y se realiza el proceso de entrenamiento:

# %%
model_1 = tf.keras.models.Sequential()
model_1.add(tf.keras.layers.Dense(units=16, activation='relu', input_shape=(remodelado,)))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=8, activation='relu'))
model_1.add(tf.keras.layers.Dense(units=num_clase, activation='softmax'))

model_1.compile(optimizer=own_sgd, 
                        loss='categorical_crossentropy',
                        metrics=['accuracy'])

epoca = 50
lote = 128
validacion = 0.2 

history = model_1.fit(X_train, Y_train, 
                    batch_size = lote, 
                    epochs = epoca, 
                    validation_split = validacion, 
                    callbacks = callback,
                    verbose = 1)
# Out:
# Epoch 1/50
# 375/375 [==============================] - 3s 5ms/step - loss: 1.2835 - accuracy: 0.5312 - val_loss: 0.5714 - val_accuracy: 0.8453
# Epoch 2/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.4086 - accuracy: 0.8848 - val_loss: 0.3181 - val_accuracy: 0.9103
# Epoch 3/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2765 - accuracy: 0.9206 - val_loss: 0.2675 - val_accuracy: 0.9256
# Epoch 4/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.2437 - accuracy: 0.9293 - val_loss: 0.2471 - val_accuracy: 0.9313
# Epoch 5/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.2170 - accuracy: 0.9366 - val_loss: 0.2552 - val_accuracy: 0.9319
# Epoch 6/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.2037 - accuracy: 0.9409 - val_loss: 0.2291 - val_accuracy: 0.9373
# Epoch 7/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1927 - accuracy: 0.9439 - val_loss: 0.2153 - val_accuracy: 0.9436
# Epoch 8/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1799 - accuracy: 0.9463 - val_loss: 0.2235 - val_accuracy: 0.9402
# Epoch 9/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1717 - accuracy: 0.9492 - val_loss: 0.2017 - val_accuracy: 0.9477
# Epoch 10/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1691 - accuracy: 0.9492 - val_loss: 0.1976 - val_accuracy: 0.9463
# Epoch 11/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1591 - accuracy: 0.9515 - val_loss: 0.2056 - val_accuracy: 0.9435
# Epoch 12/50
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1551 - accuracy: 0.9527 - val_loss: 0.2014 - val_accuracy: 0.9474
# Epoch 13/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1512 - accuracy: 0.9547 - val_loss: 0.2071 - val_accuracy: 0.9407
# Epoch 14/50
# 375/375 [==============================] - 2s 4ms/step - loss: 0.1475 - accuracy: 0.9557 - val_loss: 0.2141 - val_accuracy: 0.9417
# Epoch 15/50
# 375/375 [==============================] - 1s 4ms/step - loss: 0.1465 - accuracy: 0.9552 - val_loss: 0.2030 - val_accuracy: 0.9455

# %% [markdown]
# Terminado el entrenamiento, se visualiza el proceso hasta la parada temprana.

# %%
# construcción de un data.frame
df_train=pd.DataFrame(history.history)
df_train['epochs']=history.epoch

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(df_train['epochs'], df_train['loss'], label='train_loss')
ax1.plot(df_train['epochs'], df_train['val_loss'], label='val_loss')

ax2.plot(df_train['epochs'], df_train['accuracy'], label='train_acc')
ax2.plot(df_train['epochs'], df_train['val_accuracy'], label='val_acc')

ax1.legend()
ax2.legend()
plt.show()

# %%
loss_test, acc_test = model_1.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1857 - accuracy: 0.9485

# %% [markdown]
# Se observa además que la bondad de ajuste del modelo es

# %% [markdown]
# #### 2.2.4 Guardar de modelos
#
# Tras explicar la creación de redes neuronales en *tf.keras*, se indica el proceso seguido para guardar modelos:

# %%
import joblib
model_path = '../models/model.joblib' # nombre para guardar el fichero (incluye directorio de carpeta)

# %%
joblib.dump(model_funcional, model_path) # guardar modelo
# Out:
# ['../models/model.joblib']

# %%
new_model = joblib.load("model.joblib") # cargar el modelo previamente guardado
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 new_model = joblib.load("model.joblib") # cargar el modelo previamente guardado
#
# File ~\anaconda3\envs\tf_vivienda\lib\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model.joblib'

# %%
y_pred_funcional = model_funcional.predict(X_test)
y_pred_new_model = new_model.predict(X_test)

print(y_pred_funcional[0]) 
print(y_pred_new_model[0])

# %% [markdown]
# A pesar de que se recomienda guardar el modelo de la forma anterior, también nos puede interesar únicamente guardar la arquitectura o los pesos de la red. Para guardar la arquitectura se emplea la siguiente sintaxis:

# %%
config = model_funcional.get_config() # obtención de la configuración del modelo
reinitialized_model = tf.keras.Model.from_config(config) 

y_pred_funcional = model_funcional.predict(X_test)
y_pred_reinitialized_model = reinitialized_model.predict(X_test)

print(y_pred_funcional[0]) 
print(y_pred_reinitialized_model[0])

# %% [markdown]
# Como puede verse, como solo se ha guardado la arquitectura del modelo, las predicciones ahora son diferentes pues no se dispone de la información aprendida previamente durante el entrenamiento. Por último, con el siguiente código se guardan los pesos de la red.

# %%
weights = model_funcional.get_weights() # Recupera el estado del modelo (matriz de pesos en formato lista - array de numpy)

# %% [markdown]
# Para acceder a los pesos de cada capa se accede al elemento de la lista.

# %%
weights[0]  # pesos de la primera capa
